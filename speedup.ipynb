# %%
import numpy as np
from matplotlib import pyplot as plt
from sympy import*
init_printing()

# %%
workers = np.arange(1,9) 
times = [178.7,87.64 ,91.60,59.19 ,56.55,39.45,41.32,39.87]
speedup = [times[0]/t for t in times]

# %%
speedup
# Out:
# [1.0, 2.039023277042446, 1.9508733624454149, 3.0190910626795064, 3.16003536693
# 19188, 4.5297845373891, 4.3247821878025166, 4.482066716829697]

# %%
plt.plot(workers,speedup,"*")
plt.xlabel("Workers")
plt.title("Speedup for statistc scheduling")
plt.ylabel("Speedup")
plt.show()

# %%
F = symbols("F")
fractions = []
for i in range(2,9):
    eq = Eq(speedup[i-1],1/((1-F)+F/i))
    frac = solve(eq,F)[0]
    fractions.append(frac)

# %%
fractions
# Out:
# [1.01913822048126, 0.731113598209287, 0.891699309830256, 0.854434806939004, 0.
# 935086737548965, 0.89690356276814, 0.887872731633224]

# %%
workers = np.arange(2,9)

# %%
plt.plot(workers,fractions,"*")
plt.xlabel("Workers")
plt.ylabel("parallel fraction")
plt.show()

# %%
max_speedup = [1/(1-Fr) for Fr in fractions]
speedup[-3]/np.max(max_speedup)
# Out:
# 0.294043092522180

# %%
np.argmax(max_speedup)
# Out:
# 4

# %%
max_speedup
# Out:
# [-52.251461988299, 3.71904266389175, 9.23355149844992, 6.8697741470447, 15.405
# 1724137931, 9.69965623303783, 8.9184371880793]

# %%
workers = np.arange(1,8) 
times = [199.39,96.05,81.82,53.61,41.20,36.95, 34.53]
speedup = [times[0]/t for t in times]
plt.plot(workers,speedup,"*")
plt.xlabel("Workers")
plt.title("Speedup for dynamic scheduling")
plt.ylabel("Speedup")
plt.show()
